# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ALTERNATIVA CORRETA:
#
# d)

# %% [markdown]
# =====================================================================
#
# JUSTIFICATIVAS:
#
# a) ETL é a transformação antes do carregamento (conforme a ordem a sigla: Extrair, Transformar, Carregar), enquanto ELT carrega os dados e depois os transforma (conforme a ordem a sigla: Extrair, Carregar, Transformar).
#
# b) ELT se beneficia em ambientes escaláveis e em nuvem.
#
# c) No ETL, o tratamento ocorre antes de carregar os dados no banco de dados (conforme a ordem a sigla: Extrair, Transformar, Carregar).
#
# e) ETL é geralmente mais adequado para dados estruturados.
