# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Dividir o arquivo em partições com base em uma coluna frequentemente consultada (ex. data). Isso permite que apenas parte do arquivo seja carregado.
#
# - Carregar os dados em um banco de dados relacional que suporte consultas rápidas.
#
# - Utilizar um framework leve para construir a API, como Flask ou FastAPI, que consome menos recursos.
#
# - Utilizar bibliotecas que suportam paralelismo, para processar grandes volumes de dados em paralelo.
